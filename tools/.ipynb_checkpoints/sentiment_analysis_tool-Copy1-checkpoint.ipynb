# %%
from langchain.tools import tool
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import polars as pl
from datetime import datetime

# Import the full email DataFrame
from lib.load_data import df

# Import helper functions
from lib.utils import normalize_list, match_value_in_columns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31892\1279435341.py in <module>
#       5
#       6 # Import the full email DataFrame
# ----> 7 from lib.load_data import df
#       8
#       9 # Import helper functions
#
# ModuleNotFoundError: No module named 'lib.load_data'
